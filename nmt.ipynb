# %%
import pandas as pd 
import numpy as np
import string
import re

# %%
lines = pd.read_csv('Hindi_English_Truncated_Corpus.csv')
lines.head()
# Out:
#       source                                   english_sentence  \
# 0        ted  politicians do not have permission to do what ...
# 1        ted         I'd like to tell you about one such child,
# 2  indic2012  This percentage is even greater than the perce...
# 3        ted  what we really mean is that they're bad at not...
# 4  indic2012  .The ending portion of these Vedas is called U...
#
#                                       hindi_sentence
# 0  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4        इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।

# %%
lines['source'].value_counts()
# Out:
# tides        50000
# ted          39881
# indic2012    37726
# Name: source, dtype: int64

# %%
lines = lines [lines['source']!='indic2012']

# %%
lines.head(20)
# Out:
#    source                                   english_sentence  \
# 0     ted  politicians do not have permission to do what ...
# 1     ted         I'd like to tell you about one such child,
# 3     ted  what we really mean is that they're bad at not...
# 5   tides  The then Governor of Kashmir resisted transfer...
# 7     ted   And who are we to say, even, that they are wrong
# 9   tides  You may want your child to go to a school that...
# 10  tides  Please ensure that you use the appropriate form .
# 13    ted                   So there is some sort of justice
# 14  tides  The first two were found unreliable and the pr...
# 15  tides  They had justified their educational policy of...
# 18  tides  ii Register Courts , empowered to try causes f...
# 20  tides                 Of these Lahadi is a popular one .
# 21  tides  Even a concentration of 0.001 ppm of hydrogen ...
# 23    ted                                This changed slowly
# ...

# %%
pd.isnull(lines).sum()
# Out:
# source              0
# english_sentence    0
# hindi_sentence      0
# dtype: int64

# %%
lines.drop_duplicates(inplace=True)

# %%
lines['english_sentence']=lines['english_sentence'].str.lower()
lines['hindi_sentence']=lines['hindi_sentence'].str.lower()

# %%
lines['english_sentence']=lines['english_sentence'].str.replace("'","")
lines['hindi_sentence']=lines['hindi_sentence'].str.replace("'","")

# %%
lines.head()
# Out:
#   source                                   english_sentence  \
# 0    ted  politicians do not have permission to do what ...
# 1    ted          id like to tell you about one such child,
# 3    ted  what we really mean is that theyre bad at not ...
# 5  tides  the then governor of kashmir resisted transfer...
# 7    ted   and who are we to say, even, that they are wrong
#
#                                       hindi_sentence
# 0  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 3     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 5  कश्मीर के तत्कालीन गवर्नर ने इस हस्तांतरण का व...
# 7   और हम होते कौन हैं यह कहने भी वाले कि वे गलत हैं

# %%
exclude = set(string.punctuation) # Set of all special characters
# Remove all the special characters
lines['english_sentence']=lines['english_sentence'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
lines['hindi_sentence']=lines['hindi_sentence'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))

# %%
# Remove all the numeric values
lines = lines[~lines['english_sentence'].str.isnumeric()]

# %%
lines.value_counts()
# Out:
# source  english_sentence                                                                                                                                                           hindi_sentence
# ted     applause                                                                                                                                                                   तालियां                                                                                                                                                                     4
#         thank you very much                                                                                                                                                        बहुत बहुत धन्यवाद                                                                                                                                                           4
# ...

# %%
lines['english_sentence']=lines['english_sentence'].apply(lambda x: x.strip())
lines['hindi_sentence']=lines['hindi_sentence'].apply(lambda x: x.strip())
lines['english_sentence']=lines['english_sentence'].apply(lambda x: re.sub(" +", " ", x))
lines['hindi_sentence']=lines['hindi_sentence'].apply(lambda x: re.sub(" +", " ", x))

# %%
lines.head(20)
# Out:
#    source                                   english_sentence  \
# 0     ted  politicians do not have permission to do what ...
# 1     ted           id like to tell you about one such child
# 3     ted  what we really mean is that theyre bad at not ...
# 5   tides  the then governor of kashmir resisted transfer...
# 7     ted     and who are we to say even that they are wrong
# 9   tides  you may want your child to go to a school that...
# 10  tides    please ensure that you use the appropriate form
# 13    ted                   so there is some sort of justice
# 14  tides  the first two were found unreliable and the pr...
# 15  tides  they had justified their educational policy of...
# 18  tides  ii register courts empowered to try causes for...
# 20  tides                   of these lahadi is a popular one
# 21  tides  even a concentration of 0001 ppm of hydrogen s...
# 23    ted                                this changed slowly
# ...
